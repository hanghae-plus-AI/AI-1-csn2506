# %% [markdown]
# # 기본과제

# %%
import torch
import torchvision
import torchvision.transforms as transforms

# %% [markdown]
# 다음은 dataset을 준비합니다. 손글씨 dataset은 MNIST라는 유명한 dataset이 있습니다. 이 dataset은 `torchvision`에서 제공하고 있으며, 다음과 같이 다운로드 받을 수 있습니다.
#
# - Test data 준비하기
#     - Test data는 MNIST의 train data를 load하는 코드에서 `train=False`로 두면 됩니다.
#     - Train data와 마찬가지로 test data에 대한 data loader를 생성해주시면 됩니다(batch size는 동일하게 적용).
#         - Test data는 랜덤하게 섞일 필요가 없기 때문에 `shuffle=False`로 설정합니다.

# %%
transform = transforms.ToTensor()

trainset = torchvision.datasets.MNIST(
    root='./data',
    train=True,
    download=True,
    transform=transform
)

testset = torchvision.datasets.MNIST(
    root='./data',
    train=False,
    download=True,
    transform=transform
)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:01<00:00, 5108062.55it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 134900.99it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:01<00:00, 1275024.81it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 5710590.16it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %% [markdown]
# MNIST는 손글씨 사진과 어떤 숫자를 의미하는지에 대한 label의 pair들로 구성되어있습니다.
# 이 때, 우리는 PyTorch model을 사용할 것이기 때문에 손글씨 사진들을 모두 tensor로 변환해야합니다.
# 이러한 부가적인 변환들은 `torchvision.transforms`에서 제공하고 있으며, `torchvision.datasets.MNIST`에서 `transform` 인자로 받을 수 있습니다.
# 우리는 단순히 사진을 tensor로 바꾸고 싶기 때문에 `transforms.ToTensor()` transformation을 넘겨줍니다.
#
# 다음은 전체 data의 개수와 첫 번째 data를 출력한 결과입니다.

# %%
from matplotlib import pyplot as plt


print(len(trainset))
print(trainset[0][0].shape, trainset[0][1])
print(testset[0][0].shape, testset[0][1])
plt.imshow(trainset[0][0][0], cmap='gray')
plt.imshow(testset[0][0][0], cmap='gray')
# Out:
# 60000
# torch.Size([1, 28, 28]) 5
# torch.Size([1, 28, 28]) 7

# %% [markdown]
# 첫 번째 출력결과를 통해 우리는 6만장의 손글씨 data가 있는 것을 알 수 있습니다.
# 그리고 두 번째 출력결과를 통해 첫 번째 data의 shape은 (1, 28, 28)이고 5라는 숫자를 쓴 사진이라는 것을 알 수 있습니다.
# 마지막으로 `plt.imshow`를 통해 visualize 했을 때 5라는 숫자가 나오는 것을 알 수 있습니다.
#
# 다음은 SGD를 위해 dataset을 여러 개의 batch로 나누는 과정을 PyTorch로 구현한 모습입니다.

# %%
batch_size = 256

trainloader = torch.utils.data.DataLoader(
    trainset,
    batch_size=batch_size,
    shuffle=True
)

testloader = torch.utils.data.DataLoader(
    testset,
    batch_size=batch_size,
    shuffle=False
)

# %% [markdown]
# PyTorch에서는 `DataLoader`가 dataset을 인자로 받아 batch로 나눠줍니다.
# 부가적으로 `batch_size`라는 인자를 통해 batch size를 받고 있으며, `shuffle`이라는 인자를 통해 data들을 섞을지 결정해줍니다.
# 우리는 SGD가 완전 랜덤으로 batch를 구성해야 잘 동작하는 것을 알고 있기 때문에 `shuffle`에 `True`를 넘겨주고 있습니다.
#
# 다음은 첫 번째 batch를 출력한 모습입니다.

# %%
dataiter = iter(trainloader)
images, labels = next(dataiter)
print(images.shape, labels.shape)
# Out:
# torch.Size([256, 1, 28, 28]) torch.Size([256])

# %% [markdown]
# `images`는 첫 번째 batch의 image들이고 `labels`는 첫 번째 batch의 label들입니다.
# 위에서 batch size를 64로 설정했기 때문에 총 64개의 image와 label들이 있어야 합니다.
# 실제 shape 출력 결과를 보면 그렇다는 것을 알 수 있습니다.

# %%
from torch import nn


class Model(nn.Module):
  def __init__(self, input_dim, n_dim):
    super().__init__()

    self.layer1 = nn.Linear(input_dim, n_dim)
    self.layer2 = nn.Linear(n_dim, n_dim)
    self.layer3 = nn.Linear(n_dim, 10)

    self.act = nn.ReLU()

  def forward(self, x):
    x = torch.flatten(x, start_dim=1)
    x = self.act(self.layer1(x))
    x = self.act(self.layer2(x))
    x = self.act(self.layer3(x))

    return x


model = Model(28 * 28 * 1, 1024)

# %% [markdown]
# 이전의 2-layer MLP와 유사한 형태임을 알 수 있습니다.
# 여기서 특이사항은 `forward`의 첫 번째 줄에 `torch.flatten`을 사용한다는 것입니다.
# `Linear`는 이전에도 봤다시피 (n, d) 형태의 shape을 입력받습니다.
# 이미지는 (n, 1, 28, 28)이기 때문에 (n, 1 * 28 * 28)로 shape을 변환해야 선형 함수에 입력으로 주어줄 수 있게 됩니다.
# 이 역할을 수행하는 것이 바로 `torch.flatten`입니다.
# 우리는 첫 번째 shape인 n을 보존할 것이기 때문에 flatten할 차원은 `start_dim=1`로 넘겨주게 됩니다.
#
# 다음은 gradient descent를 수행해줄 optimizer를 구현하는 모습입니다.

# %%
from torch.optim import SGD

lr = 0.001
model = model.to('cuda')

optimizer = SGD(model.parameters(), lr=lr)

# %% [markdown]
# - `nn.CrossEntropyLoss` 적용하기
#     - 현재 코드는 regression model을 구현한 상태로, MSE를 loss로 사용하고 있습니다.
#     - 하지만 MNIST와 같은 분류 문제에서는 MSE는 적합하지 않습니다.
#         - MSE에 따르면 1에 해당하는 손글씨 이미지는 7에 해당하는 손글씨 이미지보다 0에 해당하는 손글씨 이미지가 더 가깝게 여겨집니다.
#         - 하지만 1은 실제로 0보다 7과 더 비슷하게 생겼습니다.
#     - 일반적으로 분류 문제는 MSE 대신 cross entropy loss를 사용합니다.
#     - PyTorch에서의 [cross entropy loss 문서](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html) 또는 [웹 자료](https://uumini.tistory.com/54)들을 통해 이해한 후, MSE를 대체하는 코드를 구현하시면 됩니다.
#         - 변경되어야 할 점은 2가지로 i) `Model`의 최종 output의 dimension과 ii) `loss` 계산 부분입니다.
#
#
# - 다음 조건들 아래에서 학습을 진행하면 됩니다.
#     - `n_epochs`=100, `batch_size`=256, `lr`=0.001.

# %% [markdown]
# 출력 결과를 보면 잘 수렴하는 것을 볼 수 있습니다.
# 이전 구현과 다른 점은 다음 두 가지입니다.
# - `for data in trainloader`를 통해 batch들을 iterate하면서 model을 학습합니다.
# - `inputs, labels = inputs.to('cuda'), labels.to('cuda')`를 통해 model의 입력으로 들어가는 tensor들을 GPU로 보냅니다.
#
# 마지막으로 첫 번째 data에 대한 예측 결과를 살펴봅시다.

# %%
import numpy as np

def accuracy(model, dataloader):
  cnt = 0
  acc = 0

  for data in dataloader:
    inputs, labels = data
    inputs, labels = inputs.to('cuda'), labels.to('cuda')

    preds = model(inputs)
    preds = torch.argmax(preds, dim=-1)

    cnt += labels.shape[0]
    acc += (labels == preds).sum().item()

  return acc / cnt

def plot_acc(train_accs, test_accs, label1='train', label2='test'):
  x = np.arange(len(train_accs))

  plt.plot(x, train_accs, label=label1)
  plt.plot(x, test_accs, label=label2)
  plt.legend()
  plt.show()


n_epochs = 100
train_accs = []
test_accs = []

for epoch in range(n_epochs):
  total_train_loss = 0.
  for data in trainloader:
    model.zero_grad()
    inputs, labels = data
    inputs, labels = inputs.to('cuda'), labels.to('cuda')

    preds = model(inputs)
    # cross entropy loss를 사용
    train_loss = nn.CrossEntropyLoss()
    loss = train_loss(preds, labels)
    loss.backward()
    optimizer.step()

    total_train_loss += loss.item()

  total_test_loss = 0.
  for data in testloader:
    model.zero_grad()
    inputs, labels = data
    inputs, labels = inputs.to('cuda'), labels.to('cuda')

    preds = model(inputs)
    # cross entropy loss를 사용
    test_loss = nn.CrossEntropyLoss()
    loss = test_loss(preds, labels)
    loss.backward()
    optimizer.step()

    total_test_loss += loss.item()


  train_acc = accuracy(model, trainloader)
  test_acc = accuracy(model, testloader)

  train_accs.append(train_acc)
  test_accs.append(test_acc)


  print(f"Epoch {epoch:3d} | Train Accuracy : {train_acc *100:.2f}% | Loss: {total_train_loss/len(trainloader.dataset):.4f}")
  print(f"Epoch {epoch:3d} | Test  Accuracy : {test_acc * 100:.2f}% | Loss: {total_test_loss/len(testloader.dataset):.4f}")

plot_acc(train_accs, test_accs)
# Out:
# Epoch   0 | Train Accuracy : 54.67% | Loss: 0.0083
# Epoch   0 | Test  Accuracy : 54.93% | Loss: 0.0084
# Epoch   1 | Train Accuracy : 55.35% | Loss: 0.0082
# Epoch   1 | Test  Accuracy : 55.64% | Loss: 0.0083
# Epoch   2 | Train Accuracy : 56.19% | Loss: 0.0080
# Epoch   2 | Test  Accuracy : 56.61% | Loss: 0.0081
# Epoch   3 | Train Accuracy : 57.06% | Loss: 0.0079
# Epoch   3 | Test  Accuracy : 57.44% | Loss: 0.0079
# Epoch   4 | Train Accuracy : 57.94% | Loss: 0.0077
# Epoch   4 | Test  Accuracy : 58.35% | Loss: 0.0077
# Epoch   5 | Train Accuracy : 58.74% | Loss: 0.0075
# Epoch   5 | Test  Accuracy : 59.14% | Loss: 0.0075
# Epoch   6 | Train Accuracy : 59.49% | Loss: 0.0073
# Epoch   6 | Test  Accuracy : 59.90% | Loss: 0.0073
# Epoch   7 | Train Accuracy : 60.26% | Loss: 0.0070
# Epoch   7 | Test  Accuracy : 60.64% | Loss: 0.0070
# Epoch   8 | Train Accuracy : 61.00% | Loss: 0.0068
# Epoch   8 | Test  Accuracy : 61.45% | Loss: 0.0068
# Epoch   9 | Train Accuracy : 61.86% | Loss: 0.0065
# Epoch   9 | Test  Accuracy : 62.31% | Loss: 0.0065
# Epoch  10 | Train Accuracy : 62.68% | Loss: 0.0063
# Epoch  10 | Test  Accuracy : 63.13% | Loss: 0.0063
# Epoch  11 | Train Accuracy : 63.59% | Loss: 0.0061
# Epoch  11 | Test  Accuracy : 64.10% | Loss: 0.0061
# Epoch  12 | Train Accuracy : 64.50% | Loss: 0.0059
# Epoch  12 | Test  Accuracy : 64.84% | Loss: 0.0059
# Epoch  13 | Train Accuracy : 65.35% | Loss: 0.0057
# Epoch  13 | Test  Accuracy : 65.68% | Loss: 0.0057
# Epoch  14 | Train Accuracy : 66.07% | Loss: 0.0055
# Epoch  14 | Test  Accuracy : 66.42% | Loss: 0.0055
# Epoch  15 | Train Accuracy : 66.80% | Loss: 0.0053
# Epoch  15 | Test  Accuracy : 67.21% | Loss: 0.0054
# Epoch  16 | Train Accuracy : 67.42% | Loss: 0.0052
# Epoch  16 | Test  Accuracy : 67.75% | Loss: 0.0052
# Epoch  17 | Train Accuracy : 68.04% | Loss: 0.0051
# Epoch  17 | Test  Accuracy : 68.22% | Loss: 0.0051
# Epoch  18 | Train Accuracy : 68.55% | Loss: 0.0050
# Epoch  18 | Test  Accuracy : 68.67% | Loss: 0.0050
# Epoch  19 | Train Accuracy : 68.90% | Loss: 0.0049
# Epoch  19 | Test  Accuracy : 68.97% | Loss: 0.0049
# Epoch  20 | Train Accuracy : 69.28% | Loss: 0.0048
# Epoch  20 | Test  Accuracy : 69.36% | Loss: 0.0048
# Epoch  21 | Train Accuracy : 69.53% | Loss: 0.0047
# Epoch  21 | Test  Accuracy : 69.66% | Loss: 0.0047
# Epoch  22 | Train Accuracy : 69.79% | Loss: 0.0046
# Epoch  22 | Test  Accuracy : 69.99% | Loss: 0.0046
# Epoch  23 | Train Accuracy : 70.04% | Loss: 0.0045
# Epoch  23 | Test  Accuracy : 70.21% | Loss: 0.0045
# Epoch  24 | Train Accuracy : 70.40% | Loss: 0.0044
# Epoch  24 | Test  Accuracy : 70.44% | Loss: 0.0045
# Epoch  25 | Train Accuracy : 70.61% | Loss: 0.0044
# Epoch  25 | Test  Accuracy : 70.57% | Loss: 0.0044
# Epoch  26 | Train Accuracy : 70.82% | Loss: 0.0043
# Epoch  26 | Test  Accuracy : 70.77% | Loss: 0.0043
# Epoch  27 | Train Accuracy : 70.98% | Loss: 0.0042
# Epoch  27 | Test  Accuracy : 70.93% | Loss: 0.0043
# Epoch  28 | Train Accuracy : 71.17% | Loss: 0.0042
# Epoch  28 | Test  Accuracy : 71.00% | Loss: 0.0042
# Epoch  29 | Train Accuracy : 71.31% | Loss: 0.0041
# Epoch  29 | Test  Accuracy : 71.13% | Loss: 0.0042
# Epoch  30 | Train Accuracy : 71.45% | Loss: 0.0041
# Epoch  30 | Test  Accuracy : 71.19% | Loss: 0.0041
# Epoch  31 | Train Accuracy : 71.57% | Loss: 0.0040
# Epoch  31 | Test  Accuracy : 71.28% | Loss: 0.0041
# Epoch  32 | Train Accuracy : 71.64% | Loss: 0.0040
# Epoch  32 | Test  Accuracy : 71.43% | Loss: 0.0040
# Epoch  33 | Train Accuracy : 71.74% | Loss: 0.0040
# Epoch  33 | Test  Accuracy : 71.58% | Loss: 0.0040
# Epoch  34 | Train Accuracy : 71.83% | Loss: 0.0039
# Epoch  34 | Test  Accuracy : 71.70% | Loss: 0.0040
# Epoch  35 | Train Accuracy : 71.91% | Loss: 0.0039
# Epoch  35 | Test  Accuracy : 71.81% | Loss: 0.0039
# Epoch  36 | Train Accuracy : 72.02% | Loss: 0.0038
# Epoch  36 | Test  Accuracy : 71.97% | Loss: 0.0039
# Epoch  37 | Train Accuracy : 72.12% | Loss: 0.0038
# Epoch  37 | Test  Accuracy : 72.06% | Loss: 0.0038
# Epoch  38 | Train Accuracy : 72.20% | Loss: 0.0038
# Epoch  38 | Test  Accuracy : 72.13% | Loss: 0.0038
# Epoch  39 | Train Accuracy : 72.29% | Loss: 0.0037
# Epoch  39 | Test  Accuracy : 72.19% | Loss: 0.0038
# Epoch  40 | Train Accuracy : 72.34% | Loss: 0.0037
# Epoch  40 | Test  Accuracy : 72.27% | Loss: 0.0038
# Epoch  41 | Train Accuracy : 72.43% | Loss: 0.0037
# Epoch  41 | Test  Accuracy : 72.33% | Loss: 0.0037
# Epoch  42 | Train Accuracy : 72.48% | Loss: 0.0037
# Epoch  42 | Test  Accuracy : 72.32% | Loss: 0.0037
# Epoch  43 | Train Accuracy : 72.52% | Loss: 0.0036
# Epoch  43 | Test  Accuracy : 72.40% | Loss: 0.0037
# Epoch  44 | Train Accuracy : 72.58% | Loss: 0.0036
# Epoch  44 | Test  Accuracy : 72.38% | Loss: 0.0037
# Epoch  45 | Train Accuracy : 72.64% | Loss: 0.0036
# Epoch  45 | Test  Accuracy : 72.48% | Loss: 0.0036
# Epoch  46 | Train Accuracy : 72.67% | Loss: 0.0036
# Epoch  46 | Test  Accuracy : 72.55% | Loss: 0.0036
# Epoch  47 | Train Accuracy : 72.72% | Loss: 0.0035
# Epoch  47 | Test  Accuracy : 72.63% | Loss: 0.0036
# Epoch  48 | Train Accuracy : 72.75% | Loss: 0.0035
# Epoch  48 | Test  Accuracy : 72.65% | Loss: 0.0036
# Epoch  49 | Train Accuracy : 72.81% | Loss: 0.0035
# Epoch  49 | Test  Accuracy : 72.75% | Loss: 0.0035
# Epoch  50 | Train Accuracy : 72.84% | Loss: 0.0035
# Epoch  50 | Test  Accuracy : 72.82% | Loss: 0.0035
# Epoch  51 | Train Accuracy : 72.89% | Loss: 0.0035
# Epoch  51 | Test  Accuracy : 72.87% | Loss: 0.0035
# Epoch  52 | Train Accuracy : 72.93% | Loss: 0.0035
# Epoch  52 | Test  Accuracy : 72.87% | Loss: 0.0035
# Epoch  53 | Train Accuracy : 72.99% | Loss: 0.0034
# Epoch  53 | Test  Accuracy : 72.91% | Loss: 0.0035
# Epoch  54 | Train Accuracy : 73.04% | Loss: 0.0034
# Epoch  54 | Test  Accuracy : 72.95% | Loss: 0.0035
# Epoch  55 | Train Accuracy : 73.08% | Loss: 0.0034
# Epoch  55 | Test  Accuracy : 72.99% | Loss: 0.0034
# Epoch  56 | Train Accuracy : 73.12% | Loss: 0.0034
# Epoch  56 | Test  Accuracy : 73.00% | Loss: 0.0034
# Epoch  57 | Train Accuracy : 73.14% | Loss: 0.0034
# Epoch  57 | Test  Accuracy : 73.04% | Loss: 0.0034
# Epoch  58 | Train Accuracy : 73.18% | Loss: 0.0034
# Epoch  58 | Test  Accuracy : 73.13% | Loss: 0.0034
# Epoch  59 | Train Accuracy : 73.22% | Loss: 0.0033
# Epoch  59 | Test  Accuracy : 73.19% | Loss: 0.0034
# Epoch  60 | Train Accuracy : 73.24% | Loss: 0.0033
# Epoch  60 | Test  Accuracy : 73.22% | Loss: 0.0034
# Epoch  61 | Train Accuracy : 73.29% | Loss: 0.0033
# Epoch  61 | Test  Accuracy : 73.21% | Loss: 0.0034
# Epoch  62 | Train Accuracy : 73.33% | Loss: 0.0033
# Epoch  62 | Test  Accuracy : 73.29% | Loss: 0.0033
# Epoch  63 | Train Accuracy : 73.35% | Loss: 0.0033
# Epoch  63 | Test  Accuracy : 73.29% | Loss: 0.0033
# Epoch  64 | Train Accuracy : 73.38% | Loss: 0.0033
# Epoch  64 | Test  Accuracy : 73.35% | Loss: 0.0033
# Epoch  65 | Train Accuracy : 73.41% | Loss: 0.0033
# Epoch  65 | Test  Accuracy : 73.37% | Loss: 0.0033
# Epoch  66 | Train Accuracy : 73.46% | Loss: 0.0033
# Epoch  66 | Test  Accuracy : 73.38% | Loss: 0.0033
# Epoch  67 | Train Accuracy : 73.47% | Loss: 0.0033
# Epoch  67 | Test  Accuracy : 73.37% | Loss: 0.0033
# Epoch  68 | Train Accuracy : 73.52% | Loss: 0.0032
# Epoch  68 | Test  Accuracy : 73.40% | Loss: 0.0033
# Epoch  69 | Train Accuracy : 73.54% | Loss: 0.0032
# Epoch  69 | Test  Accuracy : 73.41% | Loss: 0.0033
# Epoch  70 | Train Accuracy : 73.57% | Loss: 0.0032
# Epoch  70 | Test  Accuracy : 73.42% | Loss: 0.0033
# Epoch  71 | Train Accuracy : 73.61% | Loss: 0.0032
# Epoch  71 | Test  Accuracy : 73.49% | Loss: 0.0032
# Epoch  72 | Train Accuracy : 73.62% | Loss: 0.0032
# Epoch  72 | Test  Accuracy : 73.54% | Loss: 0.0032
# Epoch  73 | Train Accuracy : 73.64% | Loss: 0.0032
# Epoch  73 | Test  Accuracy : 73.54% | Loss: 0.0032
# Epoch  74 | Train Accuracy : 73.64% | Loss: 0.0032
# Epoch  74 | Test  Accuracy : 73.53% | Loss: 0.0032
# Epoch  75 | Train Accuracy : 73.67% | Loss: 0.0032
# Epoch  75 | Test  Accuracy : 73.56% | Loss: 0.0032
# Epoch  76 | Train Accuracy : 73.68% | Loss: 0.0032
# Epoch  76 | Test  Accuracy : 73.55% | Loss: 0.0032
# Epoch  77 | Train Accuracy : 73.71% | Loss: 0.0032
# Epoch  77 | Test  Accuracy : 73.55% | Loss: 0.0032
# Epoch  78 | Train Accuracy : 73.73% | Loss: 0.0032
# Epoch  78 | Test  Accuracy : 73.57% | Loss: 0.0032
# Epoch  79 | Train Accuracy : 73.74% | Loss: 0.0032
# Epoch  79 | Test  Accuracy : 73.60% | Loss: 0.0032
# Epoch  80 | Train Accuracy : 73.77% | Loss: 0.0031
# Epoch  80 | Test  Accuracy : 73.61% | Loss: 0.0032
# Epoch  81 | Train Accuracy : 73.80% | Loss: 0.0031
# Epoch  81 | Test  Accuracy : 73.66% | Loss: 0.0032
# Epoch  82 | Train Accuracy : 73.82% | Loss: 0.0031
# Epoch  82 | Test  Accuracy : 73.68% | Loss: 0.0032
# Epoch  83 | Train Accuracy : 73.84% | Loss: 0.0031
# Epoch  83 | Test  Accuracy : 73.68% | Loss: 0.0032
# Epoch  84 | Train Accuracy : 73.87% | Loss: 0.0031
# Epoch  84 | Test  Accuracy : 73.68% | Loss: 0.0031
# Epoch  85 | Train Accuracy : 73.89% | Loss: 0.0031
# Epoch  85 | Test  Accuracy : 73.68% | Loss: 0.0031
# Epoch  86 | Train Accuracy : 73.89% | Loss: 0.0031
# Epoch  86 | Test  Accuracy : 73.72% | Loss: 0.0031
# Epoch  87 | Train Accuracy : 73.91% | Loss: 0.0031
# Epoch  87 | Test  Accuracy : 73.71% | Loss: 0.0031
# Epoch  88 | Train Accuracy : 73.95% | Loss: 0.0031
# Epoch  88 | Test  Accuracy : 73.73% | Loss: 0.0031
# Epoch  89 | Train Accuracy : 73.96% | Loss: 0.0031
# Epoch  89 | Test  Accuracy : 73.73% | Loss: 0.0031
# Epoch  90 | Train Accuracy : 73.97% | Loss: 0.0031
# Epoch  90 | Test  Accuracy : 73.80% | Loss: 0.0031
# Epoch  91 | Train Accuracy : 74.00% | Loss: 0.0031
# Epoch  91 | Test  Accuracy : 73.84% | Loss: 0.0031
# Epoch  92 | Train Accuracy : 74.02% | Loss: 0.0031
# Epoch  92 | Test  Accuracy : 73.85% | Loss: 0.0031
# Epoch  93 | Train Accuracy : 74.02% | Loss: 0.0031
# Epoch  93 | Test  Accuracy : 73.88% | Loss: 0.0031
# Epoch  94 | Train Accuracy : 74.05% | Loss: 0.0031
# Epoch  94 | Test  Accuracy : 73.86% | Loss: 0.0031
# Epoch  95 | Train Accuracy : 74.06% | Loss: 0.0031
# Epoch  95 | Test  Accuracy : 73.90% | Loss: 0.0031
# Epoch  96 | Train Accuracy : 74.07% | Loss: 0.0030
# Epoch  96 | Test  Accuracy : 73.90% | Loss: 0.0031
# Epoch  97 | Train Accuracy : 74.09% | Loss: 0.0030
# Epoch  97 | Test  Accuracy : 73.89% | Loss: 0.0031
# Epoch  98 | Train Accuracy : 74.09% | Loss: 0.0030
# Epoch  98 | Test  Accuracy : 73.89% | Loss: 0.0031
# Epoch  99 | Train Accuracy : 74.12% | Loss: 0.0030
# Epoch  99 | Test  Accuracy : 73.92% | Loss: 0.0031

# %%
idx = 0

x = trainset[idx][0][None]  # (1, 1, 28, 28)
x = x.to('cuda')

print(model(x))
print(trainset[idx][1])

# %% [markdown]
# 여기서 idx를 조정하여 다른 data에 대한 출력 결과도 볼 수 있습니다.
# 예측 결과를 보시면 아직 성능이 그렇게 좋지 않은 것을 알 수 있습니다.
